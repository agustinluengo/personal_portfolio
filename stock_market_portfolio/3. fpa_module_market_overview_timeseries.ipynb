# %% [markdown]
# ## FPA module 3: market overview over time
#
# This module display time series information of multiple companies within a targeted list to visualy compare alike companies.
# Including:
# * volatility analysis
# * volume trend
# * gathering and comparing by sector/industry

# %%
#importing libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime, timedelta

import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from dash import Dash, html, dash_table, dcc, callback, Output, Input

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
tickers_list = ['AAPL', 
                'MSFT', 
                'GOOGL', 
                #'META',
                'ORCL',
                'AMZN']

# Download 2 years of historical data with 5-day intervals
historic_data = yf.download(tickers_list, period='5y', interval='1mo')
ytd_data = yf.download(tickers_list, period='ytd', interval='1d')
# Out:
# C:\Users\luengoag\AppData\Local\Temp\ipykernel_53892\3833341990.py:9: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  5 of 5 completed
# C:\Users\luengoag\AppData\Local\Temp\ipykernel_53892\3833341990.py:10: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  5 of 5 completed

# %%
close_ytd_lineplot = px.line(df_close_ytd,
                       x=df_close_ytd.index,
                       y=df_close_ytd.columns,
                       title='YTD close value in 1-day intervals')

close_ytd_lineplot.update_layout(paper_bgcolor='#343434', font_color='#FFF');
close_ytd_lineplot

# %%
close_ytd_lineplot = px.line(df_close_ytd,
                       x=df_close_ytd.index,
                       #y=df_close_ytd.columns,
                       y=df_close_ytd['AAPL'],
                       title='YTD close value in 1-day intervals')

close_ytd_lineplot.update_layout(paper_bgcolor='#343434', font_color='#FFF');
close_ytd_lineplot

# %%
vol_hist_lineplot = px.line(df_vol_hist,
                       x=df_vol_hist.index,
                       y=df_vol_hist.columns,
                       title='5Y volume in 1-month intervals')

vol_hist_lineplot.update_layout(paper_bgcolor='#343434', font_color='#FFF');
vol_hist_lineplot

# %%
vol_ytd_lineplot = px.line(df_vol_ytd,
                       x=df_vol_ytd.index,
                       y=df_vol_ytd.columns,
                       title='YTD volume in 1-day intervals')

vol_ytd_lineplot.update_layout(paper_bgcolor='#343434', font_color='#FFF');
vol_ytd_lineplot
